# %%
# %sql
CREATE CATALOG IF NOT EXISTS nyc_taxi_datalake;

CREATE SCHEMA IF NOT EXISTS nyc_taxi_datalake.bronze;
CREATE SCHEMA IF NOT EXISTS nyc_taxi_datalake.silver;
CREATE SCHEMA IF NOT EXISTS nyc_taxi_datalake.gold;

SHOW SCHEMAS IN nyc_taxi_datalake;

# %%
# %sql
DROP TABLE IF EXISTS nyc_taxi_datalake.silver.yellow_taxi;
